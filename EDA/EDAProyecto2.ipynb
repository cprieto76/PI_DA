# %% [markdown]
# # `PROYECTO INDIVIDUAL 2`
# ## `EMPRESA TELECOMUNICACIONES ARGENTINA`

# %% [markdown]
# ## ` EDA. Analisis Exploratorio de Datos`

# %%
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

# %%
# Tenemos 16 archivos csv en pagina de ENACOM https://datosabiertos.enacom.gob.ar/dashboards/20000/acceso-a-internet/
# Realizo el proceso de aplicar info para cada archivo csv y luego aplico y_dataprofiling

# %%
# Los siguientes pasos los hago para cada uno de los 16 datasets, solo los coloco una vez y voy reemplazando para luego generar
# el reporte html de ydata_profiling

# %%
# Importar archivo para trabajar como dataframes
df901 = pd.read_csv('901Internet_Accesos-por-tecnologia.csv')

# %%
df901.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           35 non-null     int64
#  1   Trimestre     35 non-null     int64
#  2   ADSL          35 non-null     int64
#  3   Porcentaje 1  34 non-null     float64
#  4   Cablemodem    35 non-null     int64
#  5   Porcentaje 2  34 non-null     float64
#  6   Fibra óptica  35 non-null     int64
#  7   Porcentaje 3  34 non-null     float64
#  8   Wireless      35 non-null     int64
#  9   Porcentaje 4  34 non-null     float64
#  10  Otros         35 non-null     int64
#  11  Porcentaje 5  34 non-null     float64
#  12  Total         35 non-null     int64
#  13  Porcentaje 6  34 non-null     float64
#  14  Periodo       35 non-null     object
# dtypes: float64(6), int64(8), object(1)
# memory usage: 4.2+ KB

# %%
df901
# Out:
#      Año  Trimestre     ADSL  Porcentaje 1  Cablemodem  Porcentaje 2  \
# 0   2022          3  1395277         -4.98     6031970          0.88
# 1   2022          2  1468333         -4.23     5979214         -1.55
# 2   2022          1  1533240         -7.50     6073426          1.49
# 3   2021          4  1657615        -15.02     5984240          2.71
# 4   2021          3  1950631         -3.37     5826257          3.27
# 5   2021          2  2018587         -7.20     5641731          4.00
# 6   2021          1  2175211         -1.75     5424782          0.99
# 7   2020          4  2213949         -2.21     5371824          2.14
# 8   2020          3  2263889         -1.38     5259351          5.08
# 9   2020          2  2295533         -0.17     5005115          2.07
# 10  2020          1  2299457         -4.77     4903674          0.41
# 11  2019          4  2414575        -17.02     4883869          1.75
# 12  2019          3  2909805         -2.70     4800091          3.55
# ...

# %% [markdown]
# ## `Herramienta para EDA`

# %% [markdown]
# ## `1) ydata_profiling`
#
# #### Herramienta para crear informes en formato HTML interactivo

# %%
# Vamos a generar reportes para cada uno de los 16 datasets de la fuente
# Repetimos el siguiente paso 15 veces quedando los reportes guardados en el directorio de trabajo

# %%
# Generamos archivo en html llamado reportXXX.html

design_report = ProfileReport(df901)
design_report.to_file(output_file='report901.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
'''Reportes Generados y alamacenados en este directorio de trabajo 

report653.html       Fuente (AccesosaInternetfijoporvelocidaddebajadaylocalidad_2776171688443389653.csv)
report700.html       Fuente (AccesosaInternetfijoportecnologiaylocalidad_2791751688443409700.csv)
report771.html       Fuente (AccesosaInternetfijoporvelocidadbajadayprovincia_2791741688443333771.csv)
report977.html       Fuente (977mapa_conectividad.xlsx)
report300.html       Fuente (300Internet_Penetracion (1).csv)
report301.html       Fuente (301Internet_Penetracion.csv)
report400.html       Fuente (400Internet_Ingresos.csv)
report500.html       Fuente (500Internet_BAF(provincia).csv)
report501.html       Fuente (501Internet_BAF.csv)
report600.html       Fuente (600Internet_Accesos-por-velocidad(provincia).csv)
report601.html       Fuente (601Internet_Accesos-por-velocidad.csv)
report800.html       Fuente (800historico_velocidad_internet(provincia).csv)
report801.html       Fuente (801historico_velocidad_internet.csv)
report900.html       Fuente (900Internet_Accesos-por-tecnologia(provincia).csv)
report901.html       Fuente (901Internet_Accesos-por-tecnologia.csv)
report185.html       Fuente (185Listadodelocalidadesconconectividadainternet185.csv)
